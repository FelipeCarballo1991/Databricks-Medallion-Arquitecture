-- %%
CREATE TABLE IF NOT EXISTS practica_lovelytics.bronze.fact_internaciones 
AS 
SELECT * 
FROM read_files( '/Volumes/practica_lovelytics/landing_zone/fact_dimension_files/fact_internaciones/internaciones.csv', 
format => 'csv', header => true, 
delimiter => ';' 
);

CREATE TABLE IF NOT EXISTS practica_lovelytics.bronze.sectores 
AS 
SELECT * 
FROM read_files( '/Volumes/practica_lovelytics/landing_zone/fact_dimension_files/dim_sectores/sectores.csv', 
format => 'csv', header => true, 
delimiter => ';' 
);

CREATE TABLE IF NOT EXISTS practica_lovelytics.bronze.pacientes 
AS 
SELECT * 
FROM read_files( '/Volumes/practica_lovelytics/landing_zone/fact_dimension_files/dim_pacientes/pacientes.csv', 
format => 'csv', header => true, 
delimiter => ';' 
);

CREATE TABLE IF NOT EXISTS practica_lovelytics.bronze.hospitales 
AS 
SELECT * 
FROM read_files( '/Volumes/practica_lovelytics/landing_zone/fact_dimension_files/dim_hospitales/hospitales.csv', 
format => 'csv', header => true, 
delimiter => ';' 
);

CREATE TABLE IF NOT EXISTS practica_lovelytics.bronze.diagnosticos 
AS 
SELECT * 
FROM read_files( '/Volumes/practica_lovelytics/landing_zone/fact_dimension_files/dim_diagnosticos/diagnosticos.csv', 
format => 'csv', header => true, 
delimiter => ';' 
);
